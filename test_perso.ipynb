# %%
import sys
sys.path.append(r"C:\Users\ythollet\Documents\GitHub\FitFlame")
from infos_perso import *

# %%
res = func_infos_personelles(
    nom="Martin",
    prenom="Lucas",
    sexe="Homme",
    age=28,
    nationalite="Française",
    localisalisation=[48.8566, 2.3522],  # Paris
    distance_rencontre=20,
    niveau_sports={"course": "avancé", "natation": "intermédiaire"},
    attentes=["partenaire d'entraînement", "compétition"],
    genre_recherche="Femme",
    min_age_recherchee=24,
    max_age_recherchee=32
)
res
# Out:
# Sportif(nom='Martin', prenom='Lucas', sexe='Homme', age=28, nationalite='Française', localisalisation=[48.8566, 2.3522], distance_rencontre=20, niveau_sports={'course': 'avancé', 'natation': 'intermédiaire'}, attentes=["partenaire d'entraînement", 'compétition'], genre_recherche='Femme', min_age_recherchee=24, max_age_recherchee=32)
